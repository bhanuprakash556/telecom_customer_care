# %%
import pandas as pd
import numpy as np
import os
import xlrd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('ggplot')
import os
# %matplotlib inline

# %%
file=pd.ExcelFile('Case_study_data.xlsx')

# %%
file.sheet_names
# Out:
# ['Active Customers ', 'Churn Customers']

# %%
churn=file.parse('Churn Customers')

# %%
active=file.parse('Active Customers ')

# %%
sns.countplot(x="FEEDBACK",data=churn)

# %%
churn_Good.to_csv('C:/Users/USER/Desktop/telecom case study/churngood')

# %%
sns.countplot(x="SERVICE_PLAN",data=churn)

# %%
sns.countplot(x="SALES_CHANNEL",data=churn)

# %%
sns.countplot(x="DIRECT_INDIRECT_CHANNEL",data=churn)

# %%
sns.countplot(x="SITE_TYPE_DESC",data=churn)

# %%
sns.countplot(x="GENDER",data=churn)

# %%
 sns.countplot(x="COMPUTER_OWNER",data=churn)

# %%
sns.countplot(x="FEEDBACK",hue="COMPUTER_OWNER",data=churn)

# %%
sns.countplot(x="FEEDBACK",hue="GENDER",data=churn)

# %%
sns.countplot(x="FEEDBACK",hue="GENDER",data=churn_Good)
