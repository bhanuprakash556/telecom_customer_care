# %%
import pandas as pd
import numpy as np
import os
import xlrd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('ggplot')
import os
# %matplotlib inline

# %%
file=pd.ExcelFile('Case_study_data.xlsx')

# %%
file.sheet_names
# Out:
# ['Active Customers ', 'Churn Customers']

# %%
active=file.parse('Active Customers ')

# %%
active
# Out:
#      SITE_ACCOUNT_NUMBER ACCOUNT_STATUS FIRST_COMMUNICATION_DATE UPGRADE_DATE  \
# 0           AMR-11112345         Active               2001-11-27   2003-12-14
# 1           AMR-14837287         Active               2003-05-02   2006-08-08
# 2           AMR-14837803         Active               2001-01-28   2004-03-17
# 3           AMR-14837821         Active               2001-11-20   2005-03-27
# 4           AMR-14839297         Active               2002-02-27   2004-06-14
# 5           AMR-14840229         Active               2002-02-05   2005-07-13
# 6           AMR-14841940         Active               2001-11-21   2003-06-05
# 7           AMR-14842501         Active               2001-07-20   2004-01-25
# 8           AMR-14847927         Active               2002-04-13   2006-02-23
# 9           AMR-14859335         Active               2002-04-09   2004-09-06
# 10          AMR-14859461         Active               2002-01-19   2004-11-07
# ...

# %%
sns.countplot(x="FEEDBACK",data=active)

# %%
sns.countplot(x="DIRECT_INDIRECT_CHANNEL",data=active)

# %%
sns.countplot(x="SITE_TYPE_DESC",data=active)

# %%
 sns.countplot(x="COMPUTER_OWNER",data=active)

# %%
sns.countplot(x="FEEDBACK",hue="COMPUTER_OWNER",data=active)
